# %%
__author__ = "Ehsaneddin Asgari"
__license__ = "GPL"
__version__ = "1.0.0"
__maintainer__ = "Ehsaneddin Asgari"
__email__ = "asgari@berkeley.edu or ehsaneddin.asgari@helmholtz-hzi.de"
__project__ = "LLP - MicroPheno"
__website__ = "https://llp.berkeley.edu/micropheno/"
import sys
sys.path.append('../')
from bootstrapping.bootstrapping import BootStrapping
from utility.file_utility import FileUtility

# %% [markdown]
# # Crohn's disease dataset

# %% [markdown]
# ### Con precalculado (non o temos)

# %%
BS=BootStrapping.load_precalculated('../../crohns_disease/results/bootstrapping_crohns_disease_prediction.pickle')

# %%
BS.plotting('results_bootstrapping_crohns_disease','crohns_disease')

# %% [markdown]
# ### Sen precalculado (O NOSO)

# %%
# LER OS FASTAQ
# devolve unha lista de arquivos fastaq (fasta_files) e un diccionario cos arquivos xunto co seu número de índice (mapping);
# é dicir, a orde na que se leron. Por exemplo, o primeiro arquivo fastaq ERR1368879 vemos que ten o índice 0

fasta_files, mapping = FileUtility.read_fasta_directory('../../crohns_disease/samples_fastq/', 'fastq')

# %%
# CONSTRUIR OBXECTO PARA O BOOTSTRAPPING
'''
input_dir: input directory or a list of files
output_dir: a directory to generate the output files
sampling_sizes: a list of sampling sizes (N's)
n_resamples: number of resamples from each file (N_R = 10)
seqtype: file suffixes fastq or fasta etc.
M: number of files from the directory to make samplings from (M)
'''

BS=BootStrapping(fasta_files,'../../crohns_disease/results/bootstrapping/', seqtype='fastq',
                 sampling_sizes=[10, 20, 50, 100, 200, 500, 1000, 2000, 5000, 10000], n_resamples=10, M=10)

# %%
# add k-mer samplings
for k in [3,4,5,6,7,8]:
    print(k,'-mer bootstrapping..')
    BS.add_kmer_sampling(k)
# Out:
# 3 -mer bootstrapping..
#  sampling size  10  is started ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-208a03843645> in <module>
#       2 for k in [3,4,5,6,7,8]:
#       3     print(k,'-mer bootstrapping..')
# ----> 4     BS.add_kmer_sampling(k)
#
# /mnt/c/users/nugof/Desktop/INFORMATICA/Curso4/TFG/TFG_Nuria/Codigos/MicroPheno/MicroPheno_bundle/MicroPheno-master/bootstrapping/bootstrapping.py in add_kmer_sampling(self, k_mer)
#      64         '''
#      65         self.N_axis[k_mer], self.D_S[k_mer], self.std_D_S[k_mer], self.D_R[k_mer], self.std_D_R[
# ---> 66             k_mer] = self.get_stats_samples(k_mer)
#      67
#      68     def get_stats_samples(self, k_mer):
#
# /mnt/c/users/nugof/Desktop/INFORMATICA/Curso4/TFG/TFG_Nuria/Codigos/MicroPheno/MicroPheno_bundle/MicroPheno-master/bootstrapping/bootstrapping.py in get_stats_samples(self, k_mer)
#      93                 comp_dist = self._get_kmer_distribution(sample_file, k_mer, -1, 1)
#      94                 resamples_kmers = self._get_kmer_distribution(sample_file, k_mer, sample_size, self.n_resamples)
# ---> 95                 distance_i.append(np.mean(get_kl_rows(np.array(resamples_kmers))))
#      96                 tot_dist_i = tot_dist_i + list(
#      97                     get_kl_rows(np.vstack((np.array(resamples_kmers), comp_dist[0])))[0:10, 10])
#
# /mnt/c/users/nugof/Desktop/INFORMATICA/Curso4/TFG/TFG_Nuria/Codigos/MicroPheno/MicroPheno_bundle/MicroPheno-master/utility/math_utility.py in get_kl_rows(A)
#      16     '''
#      17     norm_A=normalize(A+1e-100, norm='l1')
# ---> 18     return stats.entropy(norm_A.T[:,:,None], norm_A.T[:,None,:])
#
# ~/.local/share/virtualenvs/MicroPheno-master-olTIaRDi/lib/python3.5/site-packages/scipy/stats/_distn_infrastructure.py in entropy(pk, qk, base, axis)
#    2668         qk = asarray(qk)
#    2669         if qk.shape != pk.shape:
# -> 2670             raise ValueError("qk and pk must have same shape.")
#    2671         qk = 1.0*qk / np.sum(qk, axis=axis, keepdims=True)
#    2672         vec = rel_entr(pk, qk)
#
# ValueError: qk and pk must have same shape.

# %%
import matplotlib.pyplot as plt
# %pylab inline
# %matplotlib inline 

BS.plotting('results_bootstrapping_crohns_disease','crohns_disease')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# GARDAR RESULTADOS EN ARQUIVO 'bootstrapping_crohns_disease_prediction' NA RUTA QUE SE LLE INDICOU AO DEFINIR A INSTANCIA BS
BS.save_me('bootstrapping_crohns_disease_prediction')

# %% [markdown]
# # Oral bacteria

# %%
# Code for bootstrapping oral bacteria data
